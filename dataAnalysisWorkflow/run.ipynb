# %%
import os
import subprocess
from IPython.display import Image, display
import glob


subprocess.run(['python', 'pdfExtractor.py'], check=True)
subprocess.run(['python', 'graphMaker.py'], check=True)

pngs = glob.glob('/Users/stempel/Desktop/UWMRRC/Data/*.png')

for png in pngs:
    display(Image(filename=png))
# Out:
# ['/Users/stempel/Desktop/UWMRRC/Linac Measurements/June 11.pdf', '/Users/stempel/Desktop/UWMRRC/Linac Measurements/June 14.pdf', '/Users/stempel/Desktop/UWMRRC/Linac Measurements/June 18.pdf', '/Users/stempel/Desktop/UWMRRC/Linac Measurements/June 20.pdf', '/Users/stempel/Desktop/UWMRRC/Linac Measurements/June 27.pdf', '/Users/stempel/Desktop/UWMRRC/Linac Measurements/July 9.pdf']
# Dose Ratio 6 MV Mean: 1.0008 ± 0.0008
# Max = 1.004
# Min = 0.998
#
# Dose Ratio 10 MV Mean: 1.0000 ± 0.0013
# Max = 1.006
# Min = 0.997
#
# Dose Ratio 6 FFF Mean: 1.0007 ± 0.0014
# Max = 1.006
# Min = 0.996
#
# Dose Ratio 10 FFF Mean: 1.0015 ± 0.0021
# Max = 1.011
# Min = 0.997
#
# Dose Ratio 15 MV Mean: 1.0017 ± 0.0020
# Max = 1.011
# Min = 0.998
#
# Dose Ratio 6 MeV Mean: 1.0068 ± 0.0009
# Max = 1.010
# Min = 1.005
#
# Dose Ratio 9 MeV Mean: 1.0013 ± 0.0016
# Max = 1.009
# Min = 0.998
#
# Dose Ratio 12 MeV Mean: 1.0005 ± 0.0016
# Max = 1.008
# Min = 0.997
#
# Dose Ratio 15 MeV Mean: 1.0008 ± 0.0013
# ...
